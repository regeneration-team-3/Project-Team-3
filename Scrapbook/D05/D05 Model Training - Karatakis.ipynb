# %%
from itertools import combinations
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import normalize
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import AdaBoostRegressor, BaggingRegressor, GradientBoostingRegressor, RandomForestRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import SGDRegressor, Lasso, LogisticRegression
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.svm import LinearSVR, SVR
from sklearn.neural_network import MLPRegressor

# %%
df = pd.read_csv("carbi.data.csv")

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df.sample(2)
# Out:
#      cylinders  displayments  horsepower  weight  acceleration  model year  \
# 134          6         258.0       110.0    3632          18.0          74
# 345          4          81.0        60.0    1760          16.1          81
#
#      cluster   mpg  origin_1  origin_2  origin_3  origin          car name  \
# 134        1  16.0         1         0         0       1       amc matador
# 345        0  35.1         0         0         1       3  honda civic 1300
#
#      brand  mpg_scaled  cylinders_str  origin_str
# 134    amc    0.186170              6           1
# 345  honda    0.694149              4           3

# %%
temp = df[['cylinders']]
df = pd.get_dummies(df, columns=['cylinders'])
df['cylinders'] = temp
df.sample(2)
# Out:
#      displayments  horsepower  weight  acceleration  model year  cluster  \
# 30          140.0        90.0    2264          15.5          71        0
# 150         108.0        93.0    2391          15.5          74        0
#
#       mpg  origin_1  origin_2  origin_3  origin             car name  \
# 30   28.0         1         0         0       1  chevrolet vega 2300
# 150  26.0         0         0         1       3               subaru
#
#          brand  mpg_scaled  cylinders_str  origin_str  cylinders_4  \
# 30   chevrolet    0.505319              4           1            1
# 150     subaru    0.452128              4           3            1
#
#      cylinders_6  cylinders_8  cylinders
# 30             0            0          4
# 150            0            0          4

# %%
df['brand_code'] = pd.Categorical(df.brand).codes
df.sample(2)
# Out:
#      displayments  horsepower  weight  acceleration  model year  cluster  \
# 374         151.0    80.67068    3035          20.5          82        0
# 119         114.0    91.00000    2582          14.0          73        0
#
#       mpg  origin_1  origin_2  origin_3  ...        car name brand mpg_scaled  \
# 374  23.0         1         0         0  ...  amc concord dl   amc   0.372340
# 119  20.0         0         1         0  ...      audi 100ls  audi   0.292553
#
#      cylinders_str  origin_str  cylinders_4  cylinders_6  cylinders_8  \
# 374              4           1            1            0            0
# 119              4           2            1            0            0
#
#      cylinders  brand_code
# 374          4           0
# 119          4           1
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['displayments', 'horsepower', 'weight', 'acceleration', 'model year',
#        'cluster', 'mpg', 'origin_1', 'origin_2', 'origin_3', 'origin',
#        'car name', 'brand', 'mpg_scaled', 'cylinders_str', 'origin_str',
#        'cylinders_4', 'cylinders_6', 'cylinders_8', 'cylinders', 'brand_code'],
#       dtype='object')

# %%
# generate all posible attribute combinations
attributes = [
    'displayments',
    'horsepower',
    'weight',
    'acceleration',
    'model year',
    'cluster',
#     'origin_1',
#     'origin_2',
#     'origin_3',
    'origin',
    'cylinders',
#     'cylinders_4'
#     'cylinders_6'
#     'cylinders_8'
#     'brand',
    'brand_code'
]
attribute_combinations = []
for i in range(1, len(attributes)):
    for combination in combinations(attributes, i + 1):
        attribute_combinations.append(combination)

len(attribute_combinations)
# Out:
# 502

# %%
# kFold testing of all default regressors
normalized = False # used to test normalized values
folds = 5 # size of kfolds

yData = (df[['mpg']]).values.ravel()
if (normalized):
    yData = normalize(yData.reshape(1, -1))[0]

models = [
    DummyRegressor,
    
    AdaBoostRegressor,
    BaggingRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor,
    
    KernelRidge,
    
    SVR,
    LinearSVR,
    
#     LogisticRegression,
    SGDRegressor,
    Lasso,
    
    MLPRegressor
]
results = []
for modelFactory in models:
    results = []
    for attributes in attribute_combinations:
        xData = df[list(attributes)].values
        if (normalized):
            xData = normalize(xData)
        kfold = KFold(n_splits=folds)
        sumScore = 0
        for trainIndex, testIndex in kfold.split(xData):
            model = modelFactory()
            model.fit(xData[trainIndex], yData[trainIndex].ravel())
            sumScore += model.score(xData[testIndex], yData[testIndex])
        results.append([str(model), str(attributes), sumScore / folds])
        print(f"{model} - { attributes } - { sumScore / folds }")
    resultDf = pd.DataFrame(results)
    resultDf.to_csv(f"{modelFactory()}.csv") # edit file to avoid duplicates
# Out:
# DummyRegressor() - ('displayments', 'horsepower') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('weight', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# DummyRegressor() - ('displayments', 'horsepower', 'weight', 'acceleration', 'model year', 'cluster', 'origin', 'cylinders', 'brand_code') - -1.0151704813239477
# AdaBoostRegressor() - ('displayments', 'horsepower') - 0.4200208973623618
# AdaBoostRegressor() - ('displayments', 'weight') - 0.3072316636256548
# AdaBoostRegressor() - ('displayments', 'acceleration') - 0.335403967635818
# AdaBoostRegressor() - ('displayments', 'model year') - 0.6472861517678752
# AdaBoostRegressor() - ('displayments', 'cluster') - 0.357847432377383
# AdaBoostRegressor() - ('displayments', 'origin') - 0.3343837582391799
# AdaBoostRegressor() - ('displayments', 'cylinders') - 0.3648608388586266
# AdaBoostRegressor() - ('displayments', 'brand_code') - 0.35800905538620903
# AdaBoostRegressor() - ('horsepower', 'weight') - 0.3419421474585326
# AdaBoostRegressor() - ('horsepower', 'acceleration') - 0.3578960478856799
# AdaBoostRegressor() - ('horsepower', 'model year') - 0.5430157205762122
# AdaBoostRegressor() - ('horsepower', 'cluster') - 0.40645726483729855
# AdaBoostRegressor() - ('horsepower', 'origin') - 0.39176626477671983
# AdaBoostRegressor() - ('horsepower', 'cylinders') - 0.3604884614767231
# AdaBoostRegressor() - ('horsepower', 'brand_code') - 0.3165015885403554
# AdaBoostRegressor() - ('weight', 'acceleration') - 0.3092929137422497
# AdaBoostRegressor() - ('weight', 'model year') - 0.6827575311018108
# AdaBoostRegressor() - ('weight', 'cluster') - 0.33305046275562733
# AdaBoostRegressor() - ('weight', 'origin') - 0.272121347593333

# %%
# δοκιμές με παραμέτρους για να βρω τον ιδανικό συνδιασμό
yData = (df[['mpg']]).values.ravel()
xData = df[attributes].values

model = GradientBoostingRegressor()
parameters = {
#     'loss': ('huber', 'absolute_error', 'quantile'),
#     'penalty': ('l2', 'l1', 'elasticnet')
#     'solver': ['lbfgs', 'sgd', 'adam'],
#     'activation': ('identity', 'logistic', 'tanh', 'relu')
}
scoring = ('max_error', 'r2', 'explained_variance', 'neg_mean_absolute_error', 'neg_mean_squared_error')
for scorer in scoring:
    clf = GridSearchCV(
        estimator=model,
        param_grid=parameters,
        scoring=scoring,
        refit=scorer,
        cv=5
    )
    clf.fit(xData, yData)

    print((scorer, clf.best_params_, clf.best_score_))
# Out:
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -9.0667629           nan -11.59383863]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.78614173        nan 0.56609946]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.79377042        nan 0.77128197]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [-2.0284854          nan -3.26086506]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.12759525          nan -17.10736057]
#   warnings.warn(
# ('max_error', {'loss': 'huber'}, -9.066762900023125)
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.9758218           nan -11.44169943]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.78754868        nan 0.58917323]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.79448144        nan 0.76804146]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [-2.02609625         nan -3.13746459]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.07433746          nan -16.24102677]
#   warnings.warn(
# ('r2', {'loss': 'huber'}, 0.7875486793293822)
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.99796395          nan -11.42591478]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.78716982        nan 0.58577215]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.79445476        nan 0.76471358]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [-2.02853897         nan -3.13267528]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.09356453          nan -16.40456978]
#   warnings.warn(
# ('explained_variance', {'loss': 'huber'}, 0.7944547619553458)
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -9.05334489          nan -11.52219965]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.78606773        nan 0.57193184]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.79304164        nan 0.7744979 ]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [-2.03023825         nan -3.24457132]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.13192096          nan -16.94230984]
#   warnings.warn(
# ('neg_mean_absolute_error', {'loss': 'huber'}, -2.0302382533208294)
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 448, in fit
#     self._check_params()
#   File "/home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_gb.py", line 239, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -9.11720803          nan -11.55726914]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.78579801        nan 0.57544015]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.79316066        nan 0.76695185]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [-2.03078642         nan -3.1875997 ]
#   warnings.warn(
# /home/karatakis/miniconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [ -8.14212355          nan -16.55854555]
#   warnings.warn(
# ('neg_mean_squared_error', {'loss': 'huber'}, -8.142123554450595)
